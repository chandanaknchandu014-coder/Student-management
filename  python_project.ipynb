# %%
# student record manager
file_name= "student.txt"
#function to add student
def add_student():
    name=input("enter student name:")
    
    marks=input("enter marks:")
    
    file=open(file_name,"a")
    file.write(name+","+marks +"\n")
    file.close()
              
    print ("student record added successfully")
    #funtion to view all student
def view_students():
        file=open(file_name,"r")
        print("\nStudent Records")
        print("-----------------")

        for line in file:
            data= line.strip().split(",")
            print("Name:",data[0],"Marks:",data[1])

        file.close()
        # funtion to search student
def search_student():
    search_name=input("enter student name to search:")
    found=False

    file=open(file_name,"r")
    
    for line in file:
        name,marks=line.strip().split(",")
        if name.lower()==search_name.lower():
            print("Student Found")
            print("Name:",name,"Marks:",marks)
            found=True

        file.close()

        if not found:
            print("student not found")

# menu
while True:
    print("\n---student management system---")
    print("1.Add Student")
    print("2.View Students")
    print("3.Search Student")
    print("4.Exit")

    choice=input("Enter your choice:")

    if choice=="1":
        add_student()

    elif choice=="2":
        view_students()

    elif choice=="3":
        search_student()
    elif choice=="4":
        print("program closed")
        break

    else:
        print("invalid choice")
# Out:
# ---student management system---
# 1.Add Student
# 2.View Students
# 3.Search Student
# 4.Exit
# Enter your choice: 1
# enter student name: chandu
# enter marks: 90
# student record added successfully
#
# ---student management system---
# 1.Add Student
# 2.View Students
# 3.Search Student
# 4.Exit
# Enter your choice: 2
# Student Records
# -----------------
# Name: chandu Marks: 90
#
# ---student management system---
# 1.Add Student
# 2.View Students
# 3.Search Student
# 4.Exit
# Enter your choice: 3
# enter student name to search: chandu
# Student Found
# Name: chandu Marks: 90
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 61
#      58     view_students()
#      60 elif choice=="3":
# ---> 61     search_student()
#      62 elif choice=="4":
#      63     print("program closed")
#
# Cell In[1], line 32, in search_student()
#      28 found=False
#      30 file=open(file_name,"r")
# ---> 32 for line in file:
#      33     name,marks=line.strip().split(",")
#      34     if name.lower()==search_name.lower():
#
# ValueError: I/O operation on closed file.
